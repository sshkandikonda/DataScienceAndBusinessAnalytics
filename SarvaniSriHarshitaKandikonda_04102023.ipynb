# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         You have been given the role of a business analyst for an E-Commerce company and have been asked to prepare a basic report on the data. Follow the steps below for preparation of the report.
#
# Before you start analysing the data, it is always a good practice to see the size of the data, its features and feature types. If the data set is big, it is not possible to print out all the records.
#     </font>
# ####  Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ## Load the necessary libraries. Import and load the dataset with a name ECom_Data .

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
pd.options.display.max_rows = 10

# %%
# Get the Data

ECom_Data=pd.read_csv("E-Commerce.csv")

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         We have read the data and stored the data in "ECom_Data" variable </font>

# %% [markdown]
# ## Q 1.	To get familiar with the data
# ## a)	Print out the first 10 and the last 10 records of the data. (2 marks)
# ## b)	How many rows and columns are present in the dataset? Use any two different methods to extract this information. (2 + 2 + 2 marks)
# ## c)	How many object data types are there? (1 mark)
# ## d)	Is there any Boolean data type? (1 mark)
# #### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# The methods head() and tail() are used to obtain the first and last records respectively. By default, these methods return the first 5 records and last 5 records. However, we can retrieve any number of records using the following syntax:
#
# `data_set.head(no_of_rows)`
#
# `data_set.tail(no_of_rows)`

# %% [markdown]
# #### Ans 1 a)

# %%
# TO PRINT THE FIRST 10 RECORDS
ECom_Data.head(10)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
# 3  ea2406dc597bee2abb6b867fa668501f   West  24-10-2021             25-10-2021
# 4  5935ed077915347dc695744df68c565c  East   03-09-2021             04-09-2021
# 5  89fcdddaad50084e395d0928a7426afe  East   03-09-2021             04-09-2021
# 6  b9b183aa18d3a721d2ac23e7184525b0  East   03-09-2021             04-09-2021
# 7  dee64864c0419bec80fbbb94d19bc40d  East   03-09-2021             04-09-2021
# 8  595f55f2c1293f07ea9ec9fa2bb39f46  East   03-09-2021             04-09-2021
# 9  547b6585272473ae006bcfbdb47b6ae0   West  26-08-2021             27-08-2021
#
#   Delivered_Date                                       product_name  \
# ...

# %%
# TO PRINT THE LAST 10 RECORDS
ECom_Data.tail(10)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 8896  4db03bc4ccbe216cf151b2f2b904ba3f  East   01-12-2020
# 8897  4d4d6aeb13fa253499d0dd45a5abd87e   West  01-12-2020
# 8898  ea19e7ef703293d3f6c799ca9db4642d   West  01-12-2020
# 8899  19a53a958992fb575acffb5d41e7ef9e  East   01-12-2020
# 8900  09abab80c8dfdc6f268e0a6f05a0be11  North  01-12-2020
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 8896             04-12-2020     04-12-2020
# 8897             04-12-2020     04-12-2020
# 8898             04-12-2020     04-12-2020
# 8899             04-12-2020     04-12-2020
# 8900             04-12-2020     04-12-2020
# 8901             04-12-2020     04-12-2020
# ...

# %% [markdown]
# #### Ans 1 b)

# %% [markdown]
# To know the number of rows and columns, we have many ways. Here, shape attribute and info() method have been used.
#
# 1. **Shape Attribute:**
#     The shape attribute returns the tuple where the first element defines the number of rows and the second element defines the number of columns. For the dataset provided, the shape attribute returned the tuple (8906,17), which means the data set has 8906 rows and 17 columns.
#
# 2. **info() method:**
#     The info() method is used for understanding the table. It provides information about the number of rows and columns, the data type of each column, Not-null value count, and memory usage. From the output generated we can incur that the attribute 'RangeIndex' is used to return the number of rows (which is 8906) and Data columns are 17.

# %%
# TO FIND THE NUMBER OF ROWS AND COLUMNS
# METHOD 2:- info() method
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %%
# TO FIND THE NUMBER OF ROWS AND COLUMNS
# METHOD 1:- shape attribute
ECom_Data.shape
# Out:
# (8906, 17)

# %% [markdown]
# #### Ans  1 c)

# %% [markdown]
# When we use info() method over a dataframe, we can obtain information about the Data Type of the columns present in it. In the below output generated, we can see that the Data Type of every column is listed under the Dtype. At the last, we can also see the count of each data type column.
#
# In total, we have one column of float data type, two of integer data types and 14 of object data type.

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# ### Ans 1 d)

# %% [markdown]
# We can see from the output generated with the help of info() method that there are no columns with boolean data types. This can be incurred from the Dtype column which only consists of values int, float and object but no boolean.

# %%
ECom_Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8906 entries, 0 to 8905
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Customer_uniq_id            8906 non-null   object
#  1   Region                      8906 non-null   object
#  2   Order_Date                  8906 non-null   object
#  3   Expected_Delivery_Date      8906 non-null   object
#  4   Delivered_Date              8906 non-null   object
#  5   product_name                8906 non-null   object
#  6   product_main_category       8906 non-null   object
#  7   product_subcategory         8906 non-null   object
#  8   product_category_filter     8906 non-null   object
#  9   product_category_subfilter  8906 non-null   object
#  10  product_unique ID           8906 non-null   object
#  11  retail_price                8906 non-null   int64
#  12  discounted_price            8906 non-null   int64
# ...

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#  Once you are familiar with the data, you may decide that not all features are of use to you and you may want to delete the non-informative features (columns)</font>

# %% [markdown]
# ## Q 2.	Eliminating the non-informative columns.
# ## a)	Drop the columns product_specifications and description. (2 marks)
# ## b)	Which method or function is used to permanently delete the columns mentioned in part (a)? Write the code explicitly (2 marks)
# ### Note: Use the markdown feature of Python to explain your answer.

# %% [markdown]
# ### Ans 2 a)

# %% [markdown]
# **drop():**
#
# To drop a column from a dataset temporarily, we use drop() method. The syntax for the drop method is as follows:
#
# ***dataset_name.drop('column_name',axis)***
#
# However, if we want to drop multiple columns from a data set, we use:
#
# ***dataset_name.drop(['column_name1','column_name2','column_name3',...],axis)***

# %%
ECom_Data.drop(['product_specifications','description'],axis=1)
# Out:
#                       Customer_uniq_id Region  Order_Date  \
# 0     e71017e224688489edfe856f2308806d  East   24-10-2021
# 1     6286847ee2da18f587503db49511c539  East   24-10-2021
# 2     0686fec9b70e5039583a38119ca0c835   West  24-10-2021
# 3     ea2406dc597bee2abb6b867fa668501f   West  24-10-2021
# 4     5935ed077915347dc695744df68c565c  East   03-09-2021
# ...                                ...    ...         ...
# 8901  90d30478255e23621e8929ed15c2f6e4  South  01-12-2020
# 8902  20a73e3f41490a73ceeba5f17658db8f   West  01-12-2020
# 8903  5c1554cd45f9d538c2c6947dbdd59c75  East   01-12-2020
# 8904  6b737a4deca1ed0e56c179e66036e994   West  01-12-2020
# 8905  a5235ac28d3d5487f54025f9d6b57433  North  01-12-2020
#
#      Expected_Delivery_Date Delivered_Date  \
# 0                25-10-2021     25-10-2021
# 1                25-10-2021     25-10-2021
# 2                25-10-2021     25-10-2021
# 3                25-10-2021     25-10-2021
# 4                04-09-2021     04-09-2021
# ...

# %% [markdown]
# ### Ans 2 b)

# %% [markdown]
# In order to drop the columns permanently, we can do it in two ways:
# 1. Method 1:- We can assign the result after using drop to the dataset itself
# 2. Method 2:- We can use the inplace attribute provided in the drop() method. This inplace attribute will make the changes permanently in the dataset without assigning it to any other variable.
#
# To check the answer, we can run the below code.

# %%
# Method 1:- 
#ECom_Data = ECom_Data.drop(['product_specifications','description'],axis=1)

# Method 2:- 
ECom_Data.drop(['product_specifications','description'],axis=1,inplace=True)

# %%
# To check the changes after dropping the columns
ECom_Data.head(3)
# Out:
#                    Customer_uniq_id Region  Order_Date Expected_Delivery_Date  \
# 0  e71017e224688489edfe856f2308806d  East   24-10-2021             25-10-2021
# 1  6286847ee2da18f587503db49511c539  East   24-10-2021             25-10-2021
# 2  0686fec9b70e5039583a38119ca0c835   West  24-10-2021             25-10-2021
#
#   Delivered_Date                                       product_name  \
# 0     25-10-2021  Indcrown Net Embroidered Semi-stitched Lehenga...
# 1     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
# 2     25-10-2021      Shopmania Music Band A5 Notebook Spiral Bound
#
#   product_main_category    product_subcategory product_category_filter  \
# 0             Clothing       Women's Clothing             Ethnic Wear
# 1    Pens & Stationery    Diaries & Notebooks               Notebooks
# 2    Pens & Stationery    Diaries & Notebooks               Notebooks
#
#   product_category_subfilter product_unique ID  retail_price  \
# ...

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#         The next steps in this project involves summarization of data at various levels and visualization. Apparently, such simple steps are very useful to get an overall sense of the data.
#     </font>

# %% [markdown]
# ## Q 3. Here we summarize the data at Brand level.
# ## a) How many unique Brand are there? (2 marks)
# ## b) Note that each Brand contains multiple products. Show the average product_rating within each Brand (2 marks)

# %% [markdown]
# ### Ans 3 a)

# %% [markdown]
# **unique() method:** The unique method is used to return all the unique values that are present in a column. The output is returned in the form of a string. The syntax is: ***dataset_name['column_name'].unique()***
#
# To find the total unique values, we use the len() method. This method returns the count of elements present in a list.
# Thus the above answer 2484 is the unique number of brands present.

# %%
len(ECom_Data['Brand'].unique())
# Out:
# 2484

# %% [markdown]
# ### Ans 3 b)

# %% [markdown]
# Here, every record in the data frame has a different Brand name. As we want the average rating for every unique brand, we will first group the data according to the brand for which we used groupby() function.
#
# We then consider the product rating for every individual record and find the average(mean) of the rating for every brand using mean() function.
#
# Hence the code followed as:
# ***dataset_name.groupby(['column_name1'])['column_name2'].mean().sort_values(ascending=False)***
# where
# 1. First, we take the dataset
# 2. We then group the data using groupby() function within we consider the column_name1 with which we will group the results (i.e. Brand),
# 2. We then consider the coulmn_name2 which we consider the values
# 3. We use the column_name2 values to find the average using mean() function
# 4. We then use sort_values() to sort the data. To sort data in descending order, we have to use the attribute ascending in the sort_values() method.

# %%
ECom_Data.groupby(['Brand'])['product_rating'].mean().sort_values(ascending=False)
# Out:
# Brand
#  TARKAN                   5.0
# INDIANO                   5.0
# PUMPKIN PATCH             5.0
# PURE SOURCE               5.0
# BRAHAAN BLUE TAG          5.0
#                          ...
# BRIGHT HOME APPLIANCES    1.0
# TWIN TWINE                1.0
# BRECKEN PAUL              1.0
# QUENELL                   1.0
# FIRANGI                   1.0
# Name: product_rating, Length: 2484, dtype: float64

# %% [markdown]
# ## Q 4. Next we study the main categories of the products.
#
# ## a) Create an appropriate plot to show the count of items ordered for each product_main_category. (6 marks).
#
# ### Hint: Create a bar chart titled "Product Category type" where product_main_category are on x-axis and counts are on y-axis.
#
# ### Note: Both axis labels, i.e. the names of the product_main_category and counts must be clearly legible.
#
# ## b) From the plot identify for which two product_main_category(s)  maximum and minimum orders were placed. (2 marks)
#
# ## c) Write code to print out the top 5 product_main_category(s)  in descending order? (3 marks

# %% [markdown]
# **Countplot:**
#
# Because we are asked to show the count of items ordered for each product_main_category, we can use the countplot. The syntax for the countplot is as follows:
# `sns.countplot(x='column_name',data=table_name,order='column_name')`
# Here, the order attribute helps in representing the bars/bins in descending order thus making the graph look neat and helping in identifying the max and min of the column.
#
# **Plot size:**
# To determine the size of the graph to make it more visible, we can use the syntax:
# `plt.figure(figsize = (length,breadth))`
#
# **axis labels:**
# To determine the labels of the axes of the graph, we can use the syntax:
# `plt.xlabel('name of the label')`
# `plt.ylabel('name of the label')`
#
# **axis label rotation:**
# In the given question, the names of the bins are long and hence will make the graph look crooked. In order to avoid it, we can rotate the labels using the syntax:
# `plt.xticks(rotation=degree)`
#
# **graph title:**
# To name the graph, we can use the syntax:
# `plt.title('graph_title')`

# %% [markdown]
# ### Ans 4 a)

# %%
plt.figure(figsize=(10,6))

# To order the data in the graph use order attribute where we specify the column with which the bars are to be ordered.
sns.countplot(x='product_main_category',data=ECom_Data,order=ECom_Data['product_main_category'].value_counts().index)

#Because the labels for the bars are long, we rotate the labels to fit the aspect ratio of the graph
plt.xticks(rotation=90) 

#Labeling the y-axis
plt.ylabel('Count') 

#Labeling the x-axis
plt.xlabel('Product Main Category') 

#Title for the graph
plt.title('Product Category Type');

# %% [markdown]
# ### Ans 4 b)

# %% [markdown]
# From the grpah we can identify that:
#
# **Maximum:**
#
# Clothing is the Product Category Type which was ordered the most with Count nearly 3000
#
# **Minimum:**
#
# Wearable Smart Devices is the Product Category Type which was ordered the least with Count nearly 0

# %% [markdown]
# ### Ans 4 c)

# %%
# As a first step, group the data with product_main_category and count the number of entries for each category with count().
# Now sort the values using any column (here using the first column of the data set) using sort_values()
# To sort the data in descending order, using ascending attribute in the sort_values()
# To print the top 5 values, we can use head(5)
# Store this in a temporary variable say a
a = ECom_Data.groupby(['product_main_category']).count().sort_values('Customer_uniq_id',ascending=False).head(5)

# Now, every column in the dataset will represent the count of each product category type
# Hence copy the values of any column to a column named total_count and print it
a['total_count'] = a['Customer_uniq_id']
a['total_count']
# Out:
# product_main_category
# Clothing                       2943
# Mobiles & Accessories          1084
# Automotive                     1001
# Home Decor & Festive Needs      727
# Computers                       558
# Name: total_count, dtype: int64

# %% [markdown]
# Hence, the answer is
#
# Clothing with 2943 records,
#
# Mobiles & Accessories with 1084 records,
#
# Automotive with 1001 records,
#
# Home Decor & Festive Needs with 727 records, and
#
# Computers with 558 records.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     In E-commerce, both the retailers (here brands) and the company have to make profit to sustain in the business.
#     The E-Commerce company has the following rule for computing their own revenue: </font>
#
# ####     The company charges
# ####  (i) 25% on the orders having final price (discounted price) greater than 600
#
# #### (ii) 15% on the orders having final price (discounted price) greater than 350 but less than or equal to 600
#
# #### (iii) 10% on the orders having final price (discounted price) greater than 100 but less than or equal to 350
#
# #### (iv) Otherwise, 5% on the final price (discounted price)    </font>

# %% [markdown]
# ## Q 5. Find the Total Revenue generated by the E-Commerce company over all orders placed. (6 marks)
#
# #### Hint: Calculate revenue of E-commerce company using the conditions mentioned above and then do the total (sum) of all to get total Revenue.

# %% [markdown]
# ### Ans 5

# %%
data = []

# To apply the conditions given 
# This code stores the revenue for every entry of the row into the variable data
for i in ECom_Data['discounted_price']:
    if i > 600:
        data.append(( (25*i) / 100 ) + i)
    elif i > 350:
        data.append(( (15*i) / 100 ) + i)
    elif i > 100:
        data.append(( (10*i) / 100 ) + i)
    else:
        data.append(( (5*i) / 100 ) + i)

# %%
# Adding the revenue list for every entry of the table as a column to the table
ECom_Data['final'] = data
# The total revenue generated is the sum of all the revenue of the entries
round(sum(ECom_Data['final']),2)
# Out:
# 11957965.85

# %% [markdown]
# Thus, the total revenue generated by the E-Commerce site is 1,19,57,965.85.

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Now you need to find the revenue for each retailer (Brand)
#     </font>

# %% [markdown]
# ## Q6.Calculate the total BrandRevenue and list the top 10 Brand having maximum revenue in descending order (6 marks)
# #### Hint: Total BrandRevenue is BrandRevenue which is generated after all the deductions. Also, BrandRevenue is different from the E-Commerce company's revenue.
# #### Brand Revenue is the discounted price minus the Revenue (generated using the conditions given above Q5)

# %% [markdown]
# ### Ans 6

# %%
ECom_Data['brand_revenue'] = ECom_Data['final'] - ECom_Data['discounted_price']
round(sum(ECom_Data['brand_revenue']),2) # round() function rounds the decimal places
# Out:
# 2217486.85

# %% [markdown]
# The total Brand Revenue generated is 22,17,486.85.
#
# The top 10 brands are as follows:

# %%
ECom_Data.groupby(['Brand'])['brand_revenue'].sum().sort_values(ascending=False).head(10)
# Out:
# Brand
# ALLURE AUTO     166154.75
# GAGA             79130.00
# DAILYOBJECTS     60660.00
# SLIM             60114.40
# DIVINITI         47705.00
# ENTHOPIA         41048.75
# ASUS             33080.50
# SPRINGWEL        29659.50
# AUDEZE           29073.00
# REGULAR          26442.50
# Name: brand_revenue, dtype: float64

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
# Let us now investigate multiple features for each product to determine any pattern.
# </font>

# %% [markdown]
# ## Q 7. Compare prices for each product.
#
# ## a)	Draw boxplots of retail_price & discounted_price. (3 marks)
#
# ## b)	 Are there any outliers? (Yes/No) (1mark)
#
# ## c)	Create a scatterplot of retail_price (x-axis) and discounted_price (y-axis) (3 marks)

# %% [markdown]
# ### Ans 7 a)

# %%
plt.figure(figsize=(100,30))
plt.title('Box Plot of retail_price') 
sns.boxplot(x='retail_price',data=ECom_Data);

# %%
plt.figure(figsize=(200,30))
plt.title('Box Plot of discounted_price')
sns.boxplot(x='discounted_price',data=ECom_Data);

# %% [markdown]
# ### Ans 7 b)

# %% [markdown]
# Yes, there are many outliers in both discouted_price and retail_price.

# %% [markdown]
# ### Ans 7 c)

# %%
plt.figure(figsize=(8,8))
sns.scatterplot(data=ECom_Data, x='retail_price', y='discounted_price');
plt.xlabel('Retail Price')
plt.ylabel('Discounted Price');

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The next steps will enable to study brand-level information.
#     </font>

# %% [markdown]
# ## Q 8. Create a new dataframe to include the Brand specific information as stated:
# ## i.	total number of orders placed per Brand
# ## ii.	total retail_price per Brand
# ## iii.	total discounted_price per Brand, and
# ## iv.	total BrandRevenue generated per Brand.
#
# ## Also, draw a pairplot using these four features. (6 marks)

# %% [markdown]
# ### Ans 8

# %% [markdown]
# The first to create a new data frame from an old one is to retrieve each required column from the original column and storing it into a list

# %%
Brand = ECom_Data['Brand'].unique() 
Brand
len(Brand)
# Out:
# 2484

# %%
num_of_orders = ECom_Data.groupby(['Brand'])['Order_Date'].count() 
num_of_orders.head(3)
# Out:
# Brand
# 1OAK            2
# 3A AUTOCARE    41
# 3D MAT          1
# Name: Order_Date, dtype: int64

# %%
total_retail_price = ECom_Data.groupby(['Brand'])['retail_price'].sum()
total_retail_price.head(3)
# Out:
# Brand
# 1OAK             1698
# 3A AUTOCARE    107059
# 3D MAT           7250
# Name: retail_price, dtype: int64

# %%
total_discounted_price = ECom_Data.groupby(['Brand'])['discounted_price'].sum()
total_discounted_price.head(3)
# Out:
# Brand
# 1OAK            1274
# 3A AUTOCARE    74134
# 3D MAT          6999
# Name: discounted_price, dtype: int64

# %%
total_revenue = ECom_Data.groupby(['Brand'])['final'].sum()
total_revenue.head(3)
# Out:
# Brand
# 1OAK            1532.60
# 3A AUTOCARE    92620.10
# 3D MAT          8748.75
# Name: final, dtype: float64

# %%
# creating the new brand specific data frame
new_df = pd.DataFrame({'Brand':Brand,
                       'Num_Of_Orders':num_of_orders,
                       'Total_Retail_Price':total_retail_price,
                       'Total_Discounted_Price':total_discounted_price,
                       'Total_Revenue':total_revenue})

# renaming the index as brand name
new_df.set_index(Brand,inplace=True)
new_df
# Out:
#                            Brand  Num_Of_Orders  Total_Retail_Price  \
# INDCROWN                INDCROWN              2                1698
# SHOPMANIA              SHOPMANIA             41              107059
# TIARA DIARIES      TIARA DIARIES              1                7250
# KAJCI                      KAJCI              1                 399
# PACKMAN                  PACKMAN              5               17500
# ...                          ...            ...                 ...
# SHOETOPIA              SHOETOPIA              1                3999
# BEANZ                      BEANZ              5                6995
# SININA                    SININA              1                1999
# AARUSHI FASHION  AARUSHI FASHION              9               64742
# AMBIKA LAHENGA    AMBIKA LAHENGA              1                1999
#
#                  Total_Discounted_Price  Total_Revenue
# INDCROWN                           1274        1532.60
# ...

# %% [markdown]
# In the above data frame which gives the brand specific information, the index has been reset to a brand name. This helps in retrieving the data faster as we can identify and access the information using indices itself. Now that the data frame is ready, we can create a pairplot with the following code.

# %%
sns.pairplot(data=new_df[['Num_Of_Orders','Total_Retail_Price','Total_Discounted_Price','Total_Revenue']]);

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     The E-Commerce company operate in multiple regions. It is important to understand its performance in each region.
#     </font>

# %% [markdown]
# ## Q 9.Compare performance regionwise
#
# ## a)	Draw a lineplot for the monthly Revenue of E-Commerce Company for each region separately.  (4 marks)
#
# ## b)	Identify the best and the worst performing months for each region. (2 marks)
#
# #### Note: Only those days with actual orders(Order_Date) placed are present in the dataset. Assuming there were no orders on other days. Also, show Month and Year on x-axis.

# %% [markdown]
# ### Ans 9 a)

# %%
# Changing the Order_Date column to date-time format
ECom_Data['Order_Date']  = pd.to_datetime(ECom_Data['Order_Date'],dayfirst=True)
# retriving months and storing the data in a new column named month
ECom_Data['month'] = ECom_Data['Order_Date'].dt.month

# %%
# Plotting the graph with the help of the month column created above
sns.lineplot(data=ECom_Data,y='final',x='month',hue='Region',errorbar=('ci', False))
plt.xlabel('Month')
plt.ylabel('Revenue');

# %% [markdown]
# ### Ans 9 b)

# %% [markdown]
# **Worst Performing Month in every region**

# %% [markdown]
# | Region   | Month    |
# |:--------:|:--------:|
# | East     | 10       |
# | West     | 10       |
# | North    | 7        |
# | South    | 5        |

# %% [markdown]
# **Worst Performing Month in every region**

# %% [markdown]
# | Region   | Month    |
# |:--------:|:--------:|
# | East     | 8        |
# | West     | 3        |
# | North    | 8        |
# | South    | 6        |

# %% [markdown]
# <font color='blue'>
#     <font size = 5>
#     Congratulations! You have learnt how to approach a complex data and extract information out of it.
#     </font>
